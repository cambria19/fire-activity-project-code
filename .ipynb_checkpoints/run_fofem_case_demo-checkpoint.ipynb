# %% [markdown]
# # Wildfire Activity and Plume Rise Modeling Framework:
# # 2020 Creek Fire
# ***
# ## Overview of the First Order Fire Effects Model (FOFEM)

# %% [markdown]
# FOFEM was developed by the United States Forest Service (USFS) and is used to assess fuel consumption, fire behavior, smoke and soil heating, and smoke emissions. FOFEM does not assume that 100% of the fuel is consumed during combustion and uniquely distinguishes between the flaming and smoldering stages of burning: the flaming stage of fire is associated with the high-intensity (>15 kW m-2) active head of a fire, while smoldering represents longer-duration residual burning at a lower intensity (<15 kW m-2).
#
# ##### Inputs to FOFEM include:
# - Temperature
# - Wind Speed
# - Fuel Moisture (1hr-1000hr)
#     - Note: Dead fuels are classified by their diameter and the time it takes for them to gain or lose moisture
# - Wildfire Location (lat/lon)
# - Vegetation/fuel types
#
# ##### Outputs include:
# - Heat fluxes (kW m-2)
# - Emissions of key species (e.g. PM2.5, PM10, CO2)
# - Fuel Consumption (tons/acre)
#
# ### Let's run FOFEM for a sample case during the 2020 Creek Fire
# The 2020 Creek Fire broke out in the Sierra National Forest in California's Central Valley, burning approximately 380,000 acres before it was 100% contained. Notably, the Creek Fire produced a large pyroCb, reaching ~15.5 km MSL, and was one of the largest non-complex fires (from a single source, not a group of fires) in California history. The Creek Fire also exhibited erratic fire behavior likely driven by increased surface fuel loading, drought, and a record-breaking heat wave in the region. A widespread bark beetle infestation at the time led to above-average accumulation of dead fuels at the surface.
#
# ##### First load in necessary libraries and open pre-generated FOFEM inputs for the Creek Fire:

# %%
import os
original_cwd = os.getcwd() 
import numpy as np
import pandas as pd
import math
import datetime as dt
from scipy import stats
import numpy.ma as ma
import matplotlib.pyplot as plt
import multiprocessing as mp
import csv
import sys
import warnings
warnings.filterwarnings('ignore')

### Import functions
from process_fofem_outputs import agg_fofout, process_outputs, chunk_by_group, calc_mean_heatflux, calc_rel_burnarea

# %%
### Open FOFEM inputs for the Creek Fire
creek_inputs = pd.read_csv('/uufs/chpc.utah.edu/common/home/u6043241/fire_atlas/run_fofem/paper_demo/get_fofem_inputs/2020_creekfire_FA_fofem_inputs.csv', sep=",")

### To speed up FOFEM runs only initialize runs for Sugar pine -- Douglas-fir -- oak forest
# Group by datetime and grab first row for each hour
fof_inputs = creek_inputs.groupby('date_time').head(1)
fof_inputs['fuelbed_name'] = 39  # Corresponds to the Sugar pine -- Douglas-fir -- oak forest (37.51 tons/acre) fuel class

# Select the first few days of the Creek Fire, or filter to a time period of interest
fof_inputs['date_time'] = pd.to_datetime(fof_inputs['date_time'], format='%Y%m%d%H')
fof_inputs = fof_inputs[(fof_inputs['date_time'] >= '2020-09-04 21:00:00') & (fof_inputs['date_time'] <= '2020-09-08 23:00:00')].copy()
fof_inputs['date_time'] = fof_inputs['date_time'].dt.strftime('%Y%m%d%H')

# %% [markdown]
# ### Quick Visualization of FOFEM environmental conditions

# %%
### Visualize fuel moisture and meteorological condition changes
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Convert datetime columns
fof_inputs['date_time'] = pd.to_datetime(fof_inputs['date_time'], format='%Y%m%d%H')

# Filter FOFEM inputs to first full 3 days
fof_inputs = fof_inputs[(fof_inputs['date_time'] >= '2020-09-05 00:00:00') & (fof_inputs['date_time'] <= '2020-09-08 00:00:00')]

# Plot temperatures and 1-hr fuel moisture
ax.plot(fof_inputs['date_time'], fof_inputs['ambient_temp'], color = 'red', label = f"2m temperature", linewidth=2.5)
ax2.plot(fof_inputs['date_time'], fof_inputs['fmois1h'] * 100, color = 'darkblue', label = f"1-hr fuel moisture", linewidth=2.5)

# Set titles and add x-axis labels
ax.set_title(f"Creek Fire Ambient Temperatures", size=16)
ax2.set_title(f"Creek Fire 1-hr Fuel Moisture", size=16)
ax.set_xlabel('Time (UTC)', size=14)
ax2.set_xlabel('Time (UTC)', size=14)

# set font and rotation for date tick labels
ax.tick_params(axis='x', labelsize=8,rotation=45,which='major')
ax2.tick_params(axis='x', labelsize=8,rotation=45,which='major')

# Set y-axis labels and add figure legends
ax.set_ylabel(f"Temperature (°C)", size = 14, labelpad = 12)
ax2.set_ylabel(f"1-hr Fuel Moisture (%)", size = 14, labelpad = 12)
ax.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax.transAxes, fontsize= 'small')
ax2.legend(loc="upper right", bbox_to_anchor=(2.2,1), bbox_transform=ax.transAxes, fontsize= 'small')
plt.show()

# %% [markdown]
# ### Run FOFEM! First switch to directory where FOFEM is installed

# %%
### Change working directory to where FOFEM is installed
from pathlib import Path
project_root = Path('/uufs/chpc.utah.edu/common/home/u6043241/lin-group18/CW/fofem/fofem_python/src/py_fofem/')

sys.path.append(str(project_root))
os.chdir(project_root)

from mp_new_bulk_fofem_runs_flasmo import process_model_inputs

# %%
### Run FOFEM in parallel, requires switching to directory where FOFEM is installed
if __name__ == '__main__':
    # Create the num_name_dict from fccs_path
    num_name_dict = {}
    project_root = Path.cwd().parents[2]
    fccs_fuelbeds_path =  os.path.join(project_root, "fofem_python","src","py_fofem","data", "fof_fccs.csv")

    #make dictionary of fofem fuelbed names and fofem fuelbed numbers (universal)
    with open(fccs_fuelbeds_path, mode='r') as fccs_file:
        reader = csv.reader(fccs_file)
        next(reader)  # Skip header if there is one
        for row in reader:
            num_name = row[4]
            num, name = num_name.split(' ', 1)
            num_name_dict[int(num)] = num_name

    # Replace fuelbed numbers with names
    fof_inputs['fuelbed_name'] = fof_inputs['fuelbed_name'].astype(int).map(num_name_dict).fillna('')

    # Convert DataFrame to list of rows (like your original model_inputs)
    model_inputs = fof_inputs.values.tolist()

    # Process inputs in parallel
    output_totals_array = process_model_inputs(model_inputs, num_name_dict)

    # Convert output array to DataFrame
    totals_headers = ["lat", "lon", "date_time", "fuelbed_name", "timestep", "fmois1kh", "fmois100h", "fmois10h", "fmois1h", "fmoislit", "fmoisduff", "percent_crown_burn", "fuelcat", "dufftype", "met_dat_path", "ambient_temp", "windspeed", "emission_factors", "fire_type","con_ob", "consumed_flaming", "consumed_smoldering", "pm25_fla", "pm25_smo", "pm10_fla", "pm10_smo", "co_fla", "co_smo", "co2_fla", "co2_smo", "ch4_fla", "ch4_smo", "nox_fla", "nox_smo", "so2_fla", "so2_smo", "fi", "crown_fi",  "timeidx","fire_id","hourly_growth","FCCS_class_percent"]
    output_df = pd.DataFrame(output_totals_array, columns=totals_headers)
    
    # Filter out rows where columns 22-33 are all zeros
    fofem_outputs = output_df.loc[~(output_df.iloc[:, 22:34] == 0).all(axis=1)].copy()

    # Write output arrays to CSV files
    def write_output_to_csv(output_totals_array):
        # Path to output file (set to location where you want to save outputs)
        model_totals_path = os.path.join('/................')
        
        # Write output_totals_array to output CSV
        with open(model_totals_path, mode='w', newline='') as outfile:
            writer = csv.writer(outfile)
            writer.writerow(totals_headers)  # Write the header
            for row in output_totals_array:
                # Check if the first six columns are all zeroes
                if not all(value == 0 for value in row[22:34]):     # Check columns pm25 to fi (emissions and fire intensity) for when they are not all equal to zero
                    writer.writerow(row)
    
        print(f"Output written to {model_totals_path}")

    #  Write FOFEM outputs to CSV
    # write_output_to_csv(output_totals_array)
# Out:
# 2026-06-15 16:28:05,636 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,636 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,637 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,637 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,639 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,642 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,642 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,642 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,644 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,644 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,644 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,645 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,645 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,645 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,646 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,645 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,645 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,647 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,651 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,659 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,660 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,664 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,667 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,666 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,665 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,666 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,665 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,666 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,667 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,668 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,670 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,670 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,671 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,676 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,682 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,682 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,666 - INFO - Starting FOFEM run
# 2026-06-15 16:28:05,704 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,704 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,706 - INFO - loaded fuel data
# 2026-06-15 16:28:05,706 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,704 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,708 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,710 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,710 - INFO - loaded fuel data
# 2026-06-15 16:28:05,710 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,715 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,710 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,717 - INFO - saved inital load
# 2026-06-15 16:28:05,715 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,705 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,709 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,709 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,718 - INFO - loaded fuel data
# 2026-06-15 16:28:05,708 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,717 - INFO - loaded fuel data
# 2026-06-15 16:28:05,718 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,718 - INFO - loaded fuel data
# 2026-06-15 16:28:05,718 - INFO - loaded fuel data
# 2026-06-15 16:28:05,718 - INFO - loaded fuel data
# 2026-06-15 16:28:05,718 - INFO - loaded fuel data
# 2026-06-15 16:28:05,709 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,719 - INFO - saved inital load
# 2026-06-15 16:28:05,719 - INFO - loaded fuel data
# 2026-06-15 16:28:05,720 - INFO - saved inital load
# 2026-06-15 16:28:05,719 - INFO - saved inital load
# 2026-06-15 16:28:05,720 - INFO - saved inital load
# 2026-06-15 16:28:05,720 - INFO - saved inital load
# 2026-06-15 16:28:05,720 - INFO - saved inital load
# 2026-06-15 16:28:05,720 - INFO - set environmental variables
# 2026-06-15 16:28:05,721 - INFO - set environmental variables
# 2026-06-15 16:28:05,721 - INFO - saved inital load
# 2026-06-15 16:28:05,721 - INFO - set environmental variables
# 2026-06-15 16:28:05,721 - INFO - set environmental variables
# 2026-06-15 16:28:05,721 - INFO - set environmental variables
# 2026-06-15 16:28:05,721 - INFO - set environmental variables
# 2026-06-15 16:28:05,720 - INFO - loaded fuel data
# 2026-06-15 16:28:05,722 - INFO - set environmental variables
# 2026-06-15 16:28:05,724 - INFO - set_emission_factors
# 2026-06-15 16:28:05,724 - INFO - set_emission_factors
# 2026-06-15 16:28:05,724 - INFO - set_emission_factors
# 2026-06-15 16:28:05,725 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,725 - INFO - set_emission_factors
# 2026-06-15 16:28:05,725 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,725 - INFO - set_emission_factors
# 2026-06-15 16:28:05,725 - INFO - set_emission_factors
# 2026-06-15 16:28:05,725 - INFO - set_emission_factors
# 2026-06-15 16:28:05,725 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,710 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,726 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,725 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,726 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,726 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,726 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,726 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,726 - INFO - built fuelbed
# 2026-06-15 16:28:05,727 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,716 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,727 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,727 - INFO - built fuelbed
# 2026-06-15 16:28:05,727 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,727 - INFO - loaded fuel data
# 2026-06-15 16:28:05,727 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,727 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,727 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,728 - INFO - saved inital load
# 2026-06-15 16:28:05,728 - INFO - built fuelbed
# 2026-06-15 16:28:05,717 - INFO - loaded fuel data
# 2026-06-15 16:28:05,728 - INFO - built fuelbed
# 2026-06-15 16:28:05,728 - INFO - built fuelbed
# 2026-06-15 16:28:05,719 - INFO - set environmental variables
# 2026-06-15 16:28:05,720 - INFO - loaded fuel data
# 2026-06-15 16:28:05,728 - INFO - saved inital load
# 2026-06-15 16:28:05,728 - INFO - saved inital load
# 2026-06-15 16:28:05,729 - INFO - built fuelbed
# 2026-06-15 16:28:05,729 - INFO - built fuelbed
# 2026-06-15 16:28:05,729 - INFO - set environmental variables
# 2026-06-15 16:28:05,730 - INFO - saved inital load
# 2026-06-15 16:28:05,730 - INFO - set environmental variables
# 2026-06-15 16:28:05,730 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,730 - INFO - set environmental variables
# 2026-06-15 16:28:05,731 - INFO - set environmental variables
# 2026-06-15 16:28:05,732 - INFO - set_emission_factors
# 2026-06-15 16:28:05,732 - INFO - loaded fuel data
# 2026-06-15 16:28:05,728 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,733 - INFO - saved inital load
# 2026-06-15 16:28:05,733 - INFO - set_emission_factors
# 2026-06-15 16:28:05,733 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,733 - INFO - saved inital load
# 2026-06-15 16:28:05,733 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,733 - INFO - loaded fuel data
# 2026-06-15 16:28:05,734 - INFO - set_emission_factors
# 2026-06-15 16:28:05,734 - INFO - set environmental variables
# 2026-06-15 16:28:05,734 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,734 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,734 - INFO - loaded fuel data
# 2026-06-15 16:28:05,735 - INFO - saved inital load
# 2026-06-15 16:28:05,735 - INFO - set environmental variables
# 2026-06-15 16:28:05,734 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,735 - INFO - loaded fuel data
# 2026-06-15 16:28:05,717 - INFO - loaded fuel data
# 2026-06-15 16:28:05,721 - INFO - loaded fuel data
# 2026-06-15 16:28:05,735 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,735 - INFO - built fuelbed
# 2026-06-15 16:28:05,736 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,736 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,736 - INFO - saved inital load
# 2026-06-15 16:28:05,736 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,736 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,736 - INFO - saved inital load
# 2026-06-15 16:28:05,734 - INFO - set_emission_factors
# 2026-06-15 16:28:05,737 - INFO - loaded fuel data
# 2026-06-15 16:28:05,737 - INFO - loaded fuel data
# 2026-06-15 16:28:05,737 - INFO - saved inital load
# 2026-06-15 16:28:05,738 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,737 - INFO - set environmental variables
# 2026-06-15 16:28:05,738 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,738 - INFO - set_emission_factors
# 2026-06-15 16:28:05,737 - INFO - set environmental variables
# 2026-06-15 16:28:05,738 - INFO - built fuelbed
# 2026-06-15 16:28:05,738 - INFO - saved inital load
# 2026-06-15 16:28:05,738 - INFO - set_emission_factors
# 2026-06-15 16:28:05,738 - INFO - saved inital load
# 2026-06-15 16:28:05,738 - INFO - set environmental variables
# 2026-06-15 16:28:05,739 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,739 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,739 - INFO - loaded fuel data
# 2026-06-15 16:28:05,739 - INFO - set environmental variables
# 2026-06-15 16:28:05,740 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,740 - INFO - built fuelbed
# 2026-06-15 16:28:05,740 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,740 - INFO - set environmental variables
# 2026-06-15 16:28:05,740 - INFO - saved inital load
# 2026-06-15 16:28:05,740 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,741 - INFO - built fuelbed
# 2026-06-15 16:28:05,728 - INFO - loaded fuel data
# 2026-06-15 16:28:05,741 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,741 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,741 - INFO - built fuelbed
# 2026-06-15 16:28:05,740 - INFO - saved inital load
# 2026-06-15 16:28:05,729 - INFO - loaded fuel data
# 2026-06-15 16:28:05,742 - INFO - built fuelbed
# 2026-06-15 16:28:05,742 - INFO - loaded fuel data
# 2026-06-15 16:28:05,742 - INFO - set environmental variables
# 2026-06-15 16:28:05,743 - INFO - set_emission_factors
# 2026-06-15 16:28:05,741 - INFO - set_emission_factors
# 2026-06-15 16:28:05,743 - INFO - saved inital load
# 2026-06-15 16:28:05,743 - INFO - saved inital load
# 2026-06-15 16:28:05,742 - INFO - saved inital load
# 2026-06-15 16:28:05,742 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,743 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,735 - INFO - set_emission_factors
# 2026-06-15 16:28:05,744 - INFO - set_emission_factors
# 2026-06-15 16:28:05,744 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,744 - INFO - set environmental variables
# 2026-06-15 16:28:05,744 - INFO - set_emission_factors
# 2026-06-15 16:28:05,745 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,721 - INFO - loaded fuel data
# 2026-06-15 16:28:05,745 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,745 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,745 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,744 - INFO - loaded fuel data
# 2026-06-15 16:28:05,745 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,746 - INFO - built fuelbed
# 2026-06-15 16:28:05,736 - INFO - loaded fuel data
# 2026-06-15 16:28:05,746 - INFO - set environmental variables
# 2026-06-15 16:28:05,746 - INFO - saved inital load
# 2026-06-15 16:28:05,747 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,743 - INFO - set environmental variables
# 2026-06-15 16:28:05,747 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,747 - INFO - saved inital load
# 2026-06-15 16:28:05,747 - INFO - set environmental variables
# 2026-06-15 16:28:05,748 - INFO - set environmental variables
# 2026-06-15 16:28:05,748 - INFO - built fuelbed
# 2026-06-15 16:28:05,748 - INFO - set_emission_factors
# 2026-06-15 16:28:05,748 - INFO - built fuelbed
# 2026-06-15 16:28:05,748 - INFO - set environmental variables
# 2026-06-15 16:28:05,749 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,746 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,750 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,725 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,735 - INFO - set environmental variables
# 2026-06-15 16:28:05,751 - INFO - built fuelbed
# 2026-06-15 16:28:05,751 - INFO - set_emission_factors
# 2026-06-15 16:28:05,746 - INFO - saved inital load
# 2026-06-15 16:28:05,751 - INFO - loaded fuel data
# 2026-06-15 16:28:05,751 - INFO - set_emission_factors
# 2026-06-15 16:28:05,751 - INFO - set_emission_factors
# 2026-06-15 16:28:05,752 - INFO - set_emission_factors
# 2026-06-15 16:28:05,753 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,753 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,753 - INFO - set environmental variables
# 2026-06-15 16:28:05,746 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,753 - INFO - set_emission_factors
# 2026-06-15 16:28:05,746 - INFO - set_emission_factors
# 2026-06-15 16:28:05,755 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,755 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,754 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,755 - INFO - set_emission_factors
# 2026-06-15 16:28:05,756 - INFO - built fuelbed
# 2026-06-15 16:28:05,756 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,756 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,757 - INFO - built fuelbed
# 2026-06-15 16:28:05,757 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,757 - INFO - built fuelbed
# 2026-06-15 16:28:05,758 - INFO - set_emission_factors
# 2026-06-15 16:28:05,754 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,758 - INFO - built fuelbed
# 2026-06-15 16:28:05,759 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,759 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,760 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,756 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,753 - INFO - saved inital load
# 2026-06-15 16:28:05,761 - INFO - loaded fuel data
# 2026-06-15 16:28:05,742 - INFO - loaded fuel data
# 2026-06-15 16:28:05,741 - INFO - set_emission_factors
# 2026-06-15 16:28:05,762 - INFO - saved inital load
# 2026-06-15 16:28:05,763 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,764 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,764 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,762 - INFO - set environmental variables
# 2026-06-15 16:28:05,765 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,755 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,766 - INFO - built fuelbed
# 2026-06-15 16:28:05,766 - INFO - loaded fuel data
# 2026-06-15 16:28:05,746 - INFO - built fuelbed
# 2026-06-15 16:28:05,767 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,764 - INFO - loaded fuel data
# 2026-06-15 16:28:05,767 - INFO - saved inital load
# 2026-06-15 16:28:05,770 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,769 - INFO - built fuelbed
# 2026-06-15 16:28:05,770 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,765 - INFO - built fuelbed
# 2026-06-15 16:28:05,769 - INFO - set_emission_factors
# 2026-06-15 16:28:05,771 - INFO - loaded fuel data
# 2026-06-15 16:28:05,771 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,771 - INFO - loaded fuel data
# 2026-06-15 16:28:05,772 - INFO - saved inital load
# 2026-06-15 16:28:05,773 - INFO - saved inital load
# 2026-06-15 16:28:05,774 - INFO - set environmental variables
# 2026-06-15 16:28:05,774 - INFO - set environmental variables
# 2026-06-15 16:28:05,773 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,786 - INFO - set_emission_factors
# 2026-06-15 16:28:05,778 - INFO - set_emission_factors
# 2026-06-15 16:28:05,778 - INFO - set_emission_factors
# 2026-06-15 16:28:05,778 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,779 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,779 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,780 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,764 - INFO - set environmental variables
# 2026-06-15 16:28:05,776 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,780 - INFO - built fuelbed
# 2026-06-15 16:28:05,781 - INFO - built fuelbed
# 2026-06-15 16:28:05,770 - INFO - set environmental variables
# 2026-06-15 16:28:05,787 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,788 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,790 - INFO - built fuelbed
# 2026-06-15 16:28:05,759 - INFO - built fuelbed
# 2026-06-15 16:28:05,760 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,759 - INFO - built fuelbed
# 2026-06-15 16:28:05,805 - INFO - built fuelbed
# 2026-06-15 16:28:05,783 - INFO - set_emission_factors
# 2026-06-15 16:28:05,770 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:05,770 - INFO - saved inital load
# 2026-06-15 16:28:05,807 - INFO - set environmental variables
# 2026-06-15 16:28:05,805 - INFO - saved inital load
# 2026-06-15 16:28:05,772 - INFO - loaded fuel data
# 2026-06-15 16:28:05,796 - INFO - built fuelbed
# 2026-06-15 16:28:05,808 - INFO - loaded fuel data
# 2026-06-15 16:28:05,811 - INFO - set_emission_factors
# 2026-06-15 16:28:05,825 - INFO - saved inital load
# 2026-06-15 16:28:05,824 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,844 - INFO - saved inital load
# 2026-06-15 16:28:05,831 - INFO - set environmental variables
# 2026-06-15 16:28:05,833 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,860 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,868 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:05,876 - INFO - set environmental variables
# 2026-06-15 16:28:05,866 - INFO - set environmental variables
# 2026-06-15 16:28:05,896 - INFO - set_emission_factors
# 2026-06-15 16:28:05,872 - INFO - built fuelbed
# 2026-06-15 16:28:05,908 - INFO - built fuelbed
# 2026-06-15 16:28:05,909 - INFO - set_emission_factors
# 2026-06-15 16:28:05,956 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,938 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:05,943 - INFO - set_emission_factors
# 2026-06-15 16:28:05,996 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,000 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,002 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,047 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,050 - INFO - built fuelbed
# 2026-06-15 16:28:06,042 - INFO - built fuelbed
# 2026-06-15 16:28:06,094 - INFO - built fuelbed
# 2026-06-15 16:28:06,150 - INFO - burnup done, percent dw consumed = 79.56823661341669
# 2026-06-15 16:28:06,186 - INFO - FOFEM done
# 2026-06-15 16:28:06,243 - INFO - burnup done, percent dw consumed = 82.5034001384758
# 2026-06-15 16:28:06,271 - INFO - burnup done, percent dw consumed = 83.1630285328168
# 2026-06-15 16:28:06,271 - INFO - burnup done, percent dw consumed = 82.62255456858122
# 2026-06-15 16:28:06,271 - INFO - burnup done, percent dw consumed = 81.124167957377
# 2026-06-15 16:28:06,280 - INFO - FOFEM done
# 2026-06-15 16:28:06,288 - INFO - burnup done, percent dw consumed = 79.52731173404742
# 2026-06-15 16:28:06,292 - INFO - burnup done, percent dw consumed = 78.83383015588407
# 2026-06-15 16:28:06,271 - INFO - burnup done, percent dw consumed = 80.39800807156564
# 2026-06-15 16:28:06,293 - INFO - FOFEM done
# 2026-06-15 16:28:06,296 - INFO - burnup done, percent dw consumed = 79.48678951477297
# 2026-06-15 16:28:06,292 - INFO - FOFEM done
# 2026-06-15 16:28:06,294 - INFO - FOFEM done
# 2026-06-15 16:28:06,301 - INFO - FOFEM done
# 2026-06-15 16:28:06,298 - INFO - burnup done, percent dw consumed = 79.26521445746289
# 2026-06-15 16:28:06,307 - INFO - burnup done, percent dw consumed = 79.83863698528555
# 2026-06-15 16:28:06,308 - INFO - FOFEM done
# 2026-06-15 16:28:06,308 - INFO - burnup done, percent dw consumed = 76.54519374924568
# 2026-06-15 16:28:06,305 - INFO - burnup done, percent dw consumed = 82.62435482977872
# 2026-06-15 16:28:06,309 - INFO - FOFEM done
# 2026-06-15 16:28:06,296 - INFO - burnup done, percent dw consumed = 81.43630389915901
# 2026-06-15 16:28:06,310 - INFO - burnup done, percent dw consumed = 76.46073007244357
# 2026-06-15 16:28:06,298 - INFO - FOFEM done
# 2026-06-15 16:28:06,311 - INFO - FOFEM done
# 2026-06-15 16:28:06,307 - INFO - FOFEM done
# 2026-06-15 16:28:06,293 - INFO - FOFEM done
# 2026-06-15 16:28:06,295 - INFO - FOFEM done
# 2026-06-15 16:28:06,319 - INFO - FOFEM done
# 2026-06-15 16:28:06,305 - INFO - burnup done, percent dw consumed = 78.0275995456606
# 2026-06-15 16:28:06,327 - INFO - burnup done, percent dw consumed = 78.46260100637073
# 2026-06-15 16:28:06,320 - INFO - burnup done, percent dw consumed = 79.68375442563479
# 2026-06-15 16:28:06,336 - INFO - burnup done, percent dw consumed = 76.50789354497269
# 2026-06-15 16:28:06,332 - INFO - FOFEM done
# 2026-06-15 16:28:06,329 - INFO - FOFEM done
# 2026-06-15 16:28:06,343 - INFO - burnup done, percent dw consumed = 76.6808501526023
# 2026-06-15 16:28:06,345 - INFO - burnup done, percent dw consumed = 82.10893409017667
# 2026-06-15 16:28:06,346 - INFO - FOFEM done
# 2026-06-15 16:28:06,336 - INFO - burnup done, percent dw consumed = 76.76636250881421
# 2026-06-15 16:28:06,335 - INFO - burnup done, percent dw consumed = 78.36252344951417
# 2026-06-15 16:28:06,344 - INFO - FOFEM done
# 2026-06-15 16:28:06,356 - INFO - FOFEM done
# 2026-06-15 16:28:06,344 - INFO - FOFEM done
# 2026-06-15 16:28:06,344 - INFO - FOFEM done
# 2026-06-15 16:28:06,357 - INFO - FOFEM done
# 2026-06-15 16:28:06,366 - INFO - burnup done, percent dw consumed = 79.65541239331455
# 2026-06-15 16:28:06,389 - INFO - burnup done, percent dw consumed = 79.1054211662632
# 2026-06-15 16:28:06,360 - INFO - FOFEM done
# 2026-06-15 16:28:06,373 - INFO - burnup done, percent dw consumed = 81.76338812155682
# 2026-06-15 16:28:06,384 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,412 - INFO - burnup done, percent dw consumed = 77.96524345391464
# 2026-06-15 16:28:06,425 - INFO - FOFEM done
# 2026-06-15 16:28:06,401 - INFO - FOFEM done
# 2026-06-15 16:28:06,430 - INFO - FOFEM done
# 2026-06-15 16:28:06,428 - INFO - FOFEM done
# 2026-06-15 16:28:06,422 - INFO - burnup done, percent dw consumed = 82.60386842515909
# 2026-06-15 16:28:06,440 - INFO - burnup done, percent dw consumed = 76.70844355401569
# 2026-06-15 16:28:06,440 - INFO - burnup done, percent dw consumed = 79.193913290787
# 2026-06-15 16:28:06,441 - INFO - FOFEM done
# 2026-06-15 16:28:06,442 - INFO - FOFEM done
# 2026-06-15 16:28:06,456 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,457 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,461 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,450 - INFO - FOFEM done
# 2026-06-15 16:28:06,467 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,456 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,469 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,470 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,469 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,459 - INFO - burnup done, percent dw consumed = 77.85902254322158
# 2026-06-15 16:28:06,467 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,473 - INFO - FOFEM done
# 2026-06-15 16:28:06,470 - INFO - loaded fuel data
# 2026-06-15 16:28:06,477 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,480 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,480 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,478 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,468 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,468 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,481 - INFO - saved inital load
# 2026-06-15 16:28:06,481 - INFO - loaded fuel data
# 2026-06-15 16:28:06,481 - INFO - loaded fuel data
# 2026-06-15 16:28:06,482 - INFO - loaded fuel data
# 2026-06-15 16:28:06,482 - INFO - saved inital load
# 2026-06-15 16:28:06,483 - INFO - saved inital load
# 2026-06-15 16:28:06,480 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,483 - INFO - set environmental variables
# 2026-06-15 16:28:06,482 - INFO - set environmental variables
# 2026-06-15 16:28:06,483 - INFO - saved inital load
# 2026-06-15 16:28:06,484 - INFO - set environmental variables
# 2026-06-15 16:28:06,484 - INFO - loaded fuel data
# 2026-06-15 16:28:06,484 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,483 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,485 - INFO - loaded fuel data
# 2026-06-15 16:28:06,485 - INFO - loaded fuel data
# 2026-06-15 16:28:06,485 - INFO - saved inital load
# 2026-06-15 16:28:06,486 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,486 - INFO - set environmental variables
# 2026-06-15 16:28:06,487 - INFO - set_emission_factors
# 2026-06-15 16:28:06,487 - INFO - saved inital load
# 2026-06-15 16:28:06,487 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,486 - INFO - saved inital load
# 2026-06-15 16:28:06,487 - INFO - set_emission_factors
# 2026-06-15 16:28:06,488 - INFO - set environmental variables
# 2026-06-15 16:28:06,488 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,489 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,489 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,488 - INFO - set_emission_factors
# 2026-06-15 16:28:06,490 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,475 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,491 - INFO - built fuelbed
# 2026-06-15 16:28:06,491 - INFO - set_emission_factors
# 2026-06-15 16:28:06,490 - INFO - built fuelbed
# 2026-06-15 16:28:06,491 - INFO - loaded fuel data
# 2026-06-15 16:28:06,492 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,493 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,493 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,494 - INFO - built fuelbed
# 2026-06-15 16:28:06,494 - INFO - set environmental variables
# 2026-06-15 16:28:06,484 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,485 - INFO - loaded fuel data
# 2026-06-15 16:28:06,491 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,496 - INFO - saved inital load
# 2026-06-15 16:28:06,496 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,495 - INFO - loaded fuel data
# 2026-06-15 16:28:06,496 - INFO - saved inital load
# 2026-06-15 16:28:06,497 - INFO - set environmental variables
# 2026-06-15 16:28:06,498 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,498 - INFO - set environmental variables
# 2026-06-15 16:28:06,489 - INFO - set environmental variables
# 2026-06-15 16:28:06,498 - INFO - set_emission_factors
# 2026-06-15 16:28:06,499 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,499 - INFO - loaded fuel data
# 2026-06-15 16:28:06,500 - INFO - saved inital load
# 2026-06-15 16:28:06,501 - INFO - set_emission_factors
# 2026-06-15 16:28:06,500 - INFO - built fuelbed
# 2026-06-15 16:28:06,501 - INFO - set environmental variables
# 2026-06-15 16:28:06,502 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,501 - INFO - set_emission_factors
# 2026-06-15 16:28:06,503 - INFO - set_emission_factors
# 2026-06-15 16:28:06,503 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,503 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,504 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,504 - INFO - built fuelbed
# 2026-06-15 16:28:06,504 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,504 - INFO - set_emission_factors
# 2026-06-15 16:28:06,501 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,506 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,506 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,494 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,506 - INFO - saved inital load
# 2026-06-15 16:28:06,507 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,508 - INFO - built fuelbed
# 2026-06-15 16:28:06,508 - INFO - built fuelbed
# 2026-06-15 16:28:06,491 - INFO - set_emission_factors
# 2026-06-15 16:28:06,515 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,516 - INFO - loaded fuel data
# 2026-06-15 16:28:06,517 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,518 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,509 - INFO - burnup done, percent dw consumed = 80.15699116017086
# 2026-06-15 16:28:06,519 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,515 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,520 - INFO - set environmental variables
# 2026-06-15 16:28:06,519 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,511 - INFO - loaded fuel data
# 2026-06-15 16:28:06,522 - INFO - saved inital load
# 2026-06-15 16:28:06,519 - INFO - loaded fuel data
# 2026-06-15 16:28:06,523 - INFO - set environmental variables
# 2026-06-15 16:28:06,523 - INFO - set_emission_factors
# 2026-06-15 16:28:06,505 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,524 - INFO - saved inital load
# 2026-06-15 16:28:06,524 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,525 - INFO - built fuelbed
# 2026-06-15 16:28:06,525 - INFO - set environmental variables
# 2026-06-15 16:28:06,526 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,526 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,527 - INFO - built fuelbed
# 2026-06-15 16:28:06,528 - INFO - loaded fuel data
# 2026-06-15 16:28:06,514 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,528 - INFO - burnup done, percent dw consumed = 82.77677935093892
# 2026-06-15 16:28:06,530 - INFO - FOFEM done
# 2026-06-15 16:28:06,529 - INFO - saved inital load
# 2026-06-15 16:28:06,530 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,529 - INFO - set_emission_factors
# 2026-06-15 16:28:06,530 - INFO - FOFEM done
# 2026-06-15 16:28:06,531 - INFO - built fuelbed
# 2026-06-15 16:28:06,532 - INFO - set environmental variables
# 2026-06-15 16:28:06,533 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,534 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,517 - INFO - saved inital load
# 2026-06-15 16:28:06,540 - INFO - loaded fuel data
# 2026-06-15 16:28:06,511 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,506 - INFO - loaded fuel data
# 2026-06-15 16:28:06,535 - INFO - set_emission_factors
# 2026-06-15 16:28:06,546 - INFO - loaded fuel data
# 2026-06-15 16:28:06,546 - INFO - burnup done, percent dw consumed = 78.09113158581266
# 2026-06-15 16:28:06,545 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,547 - INFO - saved inital load
# 2026-06-15 16:28:06,547 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,547 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,548 - INFO - set environmental variables
# 2026-06-15 16:28:06,548 - INFO - set_emission_factors
# 2026-06-15 16:28:06,527 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,547 - INFO - set environmental variables
# 2026-06-15 16:28:06,548 - INFO - FOFEM done
# 2026-06-15 16:28:06,549 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,552 - INFO - set_emission_factors
# 2026-06-15 16:28:06,551 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,551 - INFO - built fuelbed
# 2026-06-15 16:28:06,552 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,550 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,552 - INFO - set_emission_factors
# 2026-06-15 16:28:06,553 - INFO - built fuelbed
# 2026-06-15 16:28:06,553 - INFO - built fuelbed
# 2026-06-15 16:28:06,554 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,556 - INFO - loaded fuel data
# 2026-06-15 16:28:06,554 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,559 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,568 - INFO - loaded fuel data
# 2026-06-15 16:28:06,569 - INFO - saved inital load
# 2026-06-15 16:28:06,570 - INFO - set environmental variables
# 2026-06-15 16:28:06,545 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,573 - INFO - set_emission_factors
# 2026-06-15 16:28:06,549 - INFO - saved inital load
# 2026-06-15 16:28:06,577 - INFO - built fuelbed
# 2026-06-15 16:28:06,582 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,586 - INFO - set environmental variables
# 2026-06-15 16:28:06,584 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,546 - INFO - saved inital load
# 2026-06-15 16:28:06,575 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,567 - INFO - saved inital load
# 2026-06-15 16:28:06,589 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,578 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,591 - INFO - set_emission_factors
# 2026-06-15 16:28:06,593 - INFO - built fuelbed
# 2026-06-15 16:28:06,577 - INFO - built fuelbed
# 2026-06-15 16:28:06,595 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,595 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,566 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,597 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,597 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,602 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,605 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,606 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,597 - INFO - loaded fuel data
# 2026-06-15 16:28:06,606 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,606 - INFO - loaded fuel data
# 2026-06-15 16:28:06,606 - INFO - loaded fuel data
# 2026-06-15 16:28:06,607 - INFO - built fuelbed
# 2026-06-15 16:28:06,608 - INFO - saved inital load
# 2026-06-15 16:28:06,609 - INFO - set environmental variables
# 2026-06-15 16:28:06,609 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,601 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,610 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,612 - INFO - built fuelbed
# 2026-06-15 16:28:06,608 - INFO - loaded fuel data
# 2026-06-15 16:28:06,614 - INFO - set_emission_factors
# 2026-06-15 16:28:06,615 - INFO - saved inital load
# 2026-06-15 16:28:06,609 - INFO - set environmental variables
# 2026-06-15 16:28:06,616 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,616 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,617 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,618 - INFO - loaded fuel data
# 2026-06-15 16:28:06,618 - INFO - burnup done, percent dw consumed = 82.99812181529767
# 2026-06-15 16:28:06,618 - INFO - built fuelbed
# 2026-06-15 16:28:06,619 - INFO - saved inital load
# 2026-06-15 16:28:06,619 - INFO - FOFEM done
# 2026-06-15 16:28:06,621 - INFO - saved inital load
# 2026-06-15 16:28:06,622 - INFO - set environmental variables
# 2026-06-15 16:28:06,622 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,623 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,601 - INFO - set environmental variables
# 2026-06-15 16:28:06,626 - INFO - set_emission_factors
# 2026-06-15 16:28:06,627 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,607 - INFO - saved inital load
# 2026-06-15 16:28:06,628 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,617 - INFO - set environmental variables
# 2026-06-15 16:28:06,629 - INFO - set environmental variables
# 2026-06-15 16:28:06,630 - INFO - built fuelbed
# 2026-06-15 16:28:06,611 - INFO - loaded fuel data
# 2026-06-15 16:28:06,632 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,633 - INFO - set_emission_factors
# 2026-06-15 16:28:06,633 - INFO - set_emission_factors
# 2026-06-15 16:28:06,633 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,621 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,639 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,639 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,620 - INFO - set environmental variables
# 2026-06-15 16:28:06,639 - INFO - set_emission_factors
# 2026-06-15 16:28:06,641 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,642 - INFO - built fuelbed
# 2026-06-15 16:28:06,644 - INFO - set_emission_factors
# 2026-06-15 16:28:06,645 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,646 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,647 - INFO - built fuelbed
# 2026-06-15 16:28:06,637 - INFO - saved inital load
# 2026-06-15 16:28:06,634 - INFO - set_emission_factors
# 2026-06-15 16:28:06,650 - INFO - loaded fuel data
# 2026-06-15 16:28:06,650 - INFO - saved inital load
# 2026-06-15 16:28:06,640 - INFO - loaded fuel data
# 2026-06-15 16:28:06,651 - INFO - set environmental variables
# 2026-06-15 16:28:06,649 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,641 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,654 - INFO - set_emission_factors
# 2026-06-15 16:28:06,654 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,655 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,656 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,656 - INFO - built fuelbed
# 2026-06-15 16:28:06,640 - INFO - loaded fuel data
# 2026-06-15 16:28:06,650 - INFO - set environmental variables
# 2026-06-15 16:28:06,641 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,668 - INFO - saved inital load
# 2026-06-15 16:28:06,669 - INFO - set environmental variables
# 2026-06-15 16:28:06,670 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,671 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,657 - INFO - built fuelbed
# 2026-06-15 16:28:06,672 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,673 - INFO - saved inital load
# 2026-06-15 16:28:06,673 - INFO - built fuelbed
# 2026-06-15 16:28:06,674 - INFO - set environmental variables
# 2026-06-15 16:28:06,666 - INFO - built fuelbed
# 2026-06-15 16:28:06,673 - INFO - set_emission_factors
# 2026-06-15 16:28:06,668 - INFO - set_emission_factors
# 2026-06-15 16:28:06,693 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,677 - INFO - set_emission_factors
# 2026-06-15 16:28:06,696 - INFO - burnup done, percent dw consumed = 81.60090115853376
# 2026-06-15 16:28:06,688 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,703 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,704 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,705 - INFO - loaded fuel data
# 2026-06-15 16:28:06,704 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,706 - INFO - saved inital load
# 2026-06-15 16:28:06,707 - INFO - set environmental variables
# 2026-06-15 16:28:06,709 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,710 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,712 - INFO - loaded fuel data
# 2026-06-15 16:28:06,713 - INFO - built fuelbed
# 2026-06-15 16:28:06,713 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,715 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,716 - INFO - built fuelbed
# 2026-06-15 16:28:06,701 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,698 - INFO - FOFEM done
# 2026-06-15 16:28:06,712 - INFO - set_emission_factors
# 2026-06-15 16:28:06,725 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,739 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,730 - INFO - loaded fuel data
# 2026-06-15 16:28:06,744 - INFO - burnup done, percent dw consumed = 80.30797011545555
# 2026-06-15 16:28:06,745 - INFO - saved inital load
# 2026-06-15 16:28:06,746 - INFO - saved inital load
# 2026-06-15 16:28:06,745 - INFO - FOFEM done
# 2026-06-15 16:28:06,740 - INFO - loaded fuel data
# 2026-06-15 16:28:06,752 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,723 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,754 - INFO - built fuelbed
# 2026-06-15 16:28:06,726 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,746 - INFO - set environmental variables
# 2026-06-15 16:28:06,773 - INFO - built fuelbed
# 2026-06-15 16:28:06,763 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,771 - INFO - set_emission_factors
# 2026-06-15 16:28:06,808 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,787 - INFO - set environmental variables
# 2026-06-15 16:28:06,789 - INFO - loaded fuel data
# 2026-06-15 16:28:06,785 - INFO - saved inital load
# 2026-06-15 16:28:06,826 - INFO - set environmental variables
# 2026-06-15 16:28:06,827 - INFO - saved inital load
# 2026-06-15 16:28:06,820 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,843 - INFO - set_emission_factors
# 2026-06-15 16:28:06,852 - INFO - set_emission_factors
# 2026-06-15 16:28:06,863 - INFO - set environmental variables
# 2026-06-15 16:28:06,857 - INFO - built fuelbed
# 2026-06-15 16:28:06,877 - INFO - set_emission_factors
# 2026-06-15 16:28:06,868 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,881 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,885 - INFO - burnup done, percent dw consumed = 76.44241816364871
# 2026-06-15 16:28:06,887 - INFO - FOFEM done
# 2026-06-15 16:28:06,892 - INFO - Starting FOFEM run
# 2026-06-15 16:28:06,903 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,886 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,878 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:06,882 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,918 - INFO - built fuelbed
# 2026-06-15 16:28:06,924 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,932 - INFO - built fuelbed
# 2026-06-15 16:28:06,922 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:06,946 - INFO - built fuelbed
# 2026-06-15 16:28:06,915 - INFO - loaded fuel data
# 2026-06-15 16:28:06,963 - INFO - saved inital load
# 2026-06-15 16:28:06,930 - INFO - 039 Sugar pine -- Douglas-fir -- oak forest
# 2026-06-15 16:28:06,966 - INFO - loaded fuel data
# 2026-06-15 16:28:07,010 - INFO - saved inital load
# 2026-06-15 16:28:06,985 - INFO - set environmental variables
# 2026-06-15 16:28:07,029 - INFO - burnup done, percent dw consumed = 82.24282429247128
# 2026-06-15 16:28:07,008 - INFO - burnup done, percent dw consumed = 83.07392968370546
# 2026-06-15 16:28:07,030 - INFO - FOFEM done
# 2026-06-15 16:28:07,023 - INFO - burnup done, percent dw consumed = 82.64491264641443
# 2026-06-15 16:28:07,042 - INFO - burnup done, percent dw consumed = 79.57218914191687
# 2026-06-15 16:28:07,037 - INFO - FOFEM done
# 2026-06-15 16:28:07,013 - INFO - set environmental variables
# 2026-06-15 16:28:07,050 - INFO - burnup done, percent dw consumed = 79.6300161425963
# 2026-06-15 16:28:07,018 - INFO - set_emission_factors
# 2026-06-15 16:28:07,052 - INFO - FOFEM done
# 2026-06-15 16:28:07,044 - INFO - FOFEM done
# 2026-06-15 16:28:07,043 - INFO - FOFEM done
# 2026-06-15 16:28:07,053 - INFO - burnup done, percent dw consumed = 79.06837927266534
# 2026-06-15 16:28:07,064 - INFO - burnup done, percent dw consumed = 79.77539502333799
# 2026-06-15 16:28:07,066 - INFO - burnup done, percent dw consumed = 81.9563075169108
# 2026-06-15 16:28:07,067 - INFO - FOFEM done
# 2026-06-15 16:28:07,069 - INFO - FOFEM done
# 2026-06-15 16:28:07,074 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:07,075 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:07,076 - INFO - built fuelbed
# 2026-06-15 16:28:07,080 - INFO - burnup done, percent dw consumed = 76.33928769813146
# 2026-06-15 16:28:07,080 - INFO - burnup done, percent dw consumed = 82.99827010739104
# 2026-06-15 16:28:07,083 - INFO - FOFEM done
# 2026-06-15 16:28:07,083 - INFO - FOFEM done
# 2026-06-15 16:28:07,061 - INFO - set_emission_factors
# 2026-06-15 16:28:07,088 - INFO - burnup done, percent dw consumed = 79.81486676046315
# 2026-06-15 16:28:07,090 - INFO - FOFEM done
# 2026-06-15 16:28:07,089 - INFO - burnup done, percent dw consumed = 76.75723673297789
# 2026-06-15 16:28:07,090 - INFO - FOFEM done
# 2026-06-15 16:28:07,090 - INFO - FOFEM done
# 2026-06-15 16:28:07,094 - INFO - burnup done, percent dw consumed = 82.21391725620934
# 2026-06-15 16:28:07,095 - INFO - FOFEM done
# 2026-06-15 16:28:07,108 - INFO - Percent duff calculated = 100, based on equation number 2
# 2026-06-15 16:28:07,109 - INFO - hsf manager done, duff percent consumption = 100, herb shrub percent consumption = 69.52380952380952
# 2026-06-15 16:28:07,109 - INFO - burnup done, percent dw consumed = 79.45278995357907
# 2026-06-15 16:28:07,110 - INFO - built fuelbed
# 2026-06-15 16:28:07,110 - INFO - FOFEM done
# 2026-06-15 16:28:07,115 - INFO - burnup done, percent dw consumed = 78.62524516476257
# 2026-06-15 16:28:07,116 - INFO - burnup done, percent dw consumed = 78.19598265898138
# 2026-06-15 16:28:07,116 - INFO - FOFEM done
# 2026-06-15 16:28:07,117 - INFO - FOFEM done
# 2026-06-15 16:28:07,123 - INFO - burnup done, percent dw consumed = 80.16125443622771
# 2026-06-15 16:28:07,124 - INFO - FOFEM done
# 2026-06-15 16:28:07,136 - INFO - burnup done, percent dw consumed = 79.13893646316107
# 2026-06-15 16:28:07,137 - INFO - FOFEM done
# 2026-06-15 16:28:07,170 - INFO - burnup done, percent dw consumed = 79.64990880773576
# 2026-06-15 16:28:07,171 - INFO - FOFEM done
# 2026-06-15 16:28:07,184 - INFO - burnup done, percent dw consumed = 77.4261922231603
# 2026-06-15 16:28:07,184 - INFO - burnup done, percent dw consumed = 76.6260111715457
# 2026-06-15 16:28:07,185 - INFO - FOFEM done
# 2026-06-15 16:28:07,185 - INFO - FOFEM done
# 2026-06-15 16:28:07,201 - INFO - burnup done, percent dw consumed = 82.30883967504266
# 2026-06-15 16:28:07,202 - INFO - FOFEM done
# 2026-06-15 16:28:07,206 - INFO - burnup done, percent dw consumed = 80.4573815077348
# 2026-06-15 16:28:07,207 - INFO - FOFEM done
# 2026-06-15 16:28:07,221 - INFO - burnup done, percent dw consumed = 78.75732351569026
# 2026-06-15 16:28:07,221 - INFO - FOFEM done
# 2026-06-15 16:28:07,226 - INFO - burnup done, percent dw consumed = 80.22711381946628
# 2026-06-15 16:28:07,227 - INFO - FOFEM done
# 2026-06-15 16:28:07,258 - INFO - burnup done, percent dw consumed = 79.05687033058962
# 2026-06-15 16:28:07,259 - INFO - FOFEM done
# 2026-06-15 16:28:07,267 - INFO - burnup done, percent dw consumed = 76.65029649154714
# 2026-06-15 16:28:07,268 - INFO - burnup done, percent dw consumed = 82.84250567944684
# 2026-06-15 16:28:07,268 - INFO - FOFEM done
# 2026-06-15 16:28:07,268 - INFO - FOFEM done
# 2026-06-15 16:28:07,356 - INFO - burnup done, percent dw consumed = 80.17210648781338
# 2026-06-15 16:28:07,357 - INFO - FOFEM done
# 2026-06-15 16:28:07,358 - INFO - burnup done, percent dw consumed = 78.58549631872376
# 2026-06-15 16:28:07,359 - INFO - FOFEM done
# 2026-06-15 16:28:07,373 - INFO - burnup done, percent dw consumed = 76.85722188335798
# 2026-06-15 16:28:07,374 - INFO - FOFEM done
# 2026-06-15 16:28:07,423 - INFO - burnup done, percent dw consumed = 80.5652759115675
# 2026-06-15 16:28:07,424 - INFO - FOFEM done
# 2026-06-15 16:28:07,454 - INFO - burnup done, percent dw consumed = 82.9397981055008
# 2026-06-15 16:28:07,455 - INFO - FOFEM done
# 2026-06-15 16:28:07,465 - INFO - burnup done, percent dw consumed = 77.9588833308422
# 2026-06-15 16:28:07,466 - INFO - FOFEM done
# 2026-06-15 16:28:07,487 - INFO - burnup done, percent dw consumed = 82.18436062029161
# 2026-06-15 16:28:07,488 - INFO - FOFEM done

# %% [markdown]
# ### Let's clean up the FOFEM outputs, averaging heat fluxes and emissions by hour.

# %%
### Clean up raw FOFEM outputs
# Switch back to original working directory
original_cwd = os.getcwd() 

# Average outputs by hour for each fuel category
if __name__ == '__main__':
    
    # Add flaming + smoldering emissions of a few key species
    fofem_outputs['pm25'] = fofem_outputs['pm25_fla'] + fofem_outputs['pm25_smo']
    
    fofem_outputs['pm10'] = fofem_outputs['pm10_fla'] + fofem_outputs['pm10_smo']
   
    fofem_outputs['co2'] = fofem_outputs['co2_fla'] + fofem_outputs['co2_smo']

    # Clean up FOFEM outputs, takes care of fuels that burn less than an hour or for multiple hours
    cleaned_outputs = process_outputs(fofem_outputs, 0)

# %%
### Calculate weighted heat fluxes (based on fuel classes)
cleaned_outputs['fire_year'] = cleaned_outputs['date_time'].dt.year
mean_hf = cleaned_outputs.groupby(['fire_id', 'fire_year']).apply(calc_mean_heatflux).reset_index(drop=True)
mean_hf = mean_hf.dropna()

mean_hf['fire_year'] = mean_hf['date_time'].dt.year
mean_hf = mean_hf.sort_values(by=['fire_year','fire_id'])

# %% [markdown]
# ### Plot the FOFEM-calculated heat fluxes for the first 3 days of the Creek Fire

# %%
### Plot heat fluxes for a period during the Creek Fire
fig, ax = plt.subplots(figsize=(8,4))
mean_hf = mean_hf[(mean_hf['date_time'] >= '2020-09-05 00:00:00') & (mean_hf['date_time'] <= '2020-09-08 00:00:00')]

# Plot hourly averaged heat fluxes
ax.plot(mean_hf['date_time'], mean_hf['weighted_fi'], color = 'red', label = f"Heat Flux", linewidth=2.5)

# Set axis labels
ax.set_xlabel('Time (UTC)', size=14)
ax.set_ylabel(f"Heat Fluxes (kW/m^2)", size = 14, labelpad = 12)

# Set plot title and add legend
ax.set_title(f"Creek Fire 09/05-09/08 Mean Heat Fluxes", size=16)
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax.transAxes, fontsize= 'small')

# Set font and rotation for date tick labels
ax.tick_params(axis='x', labelsize=8,rotation=45,which='major')
plt.gcf().autofmt_xdate() 
plt.show()

# %% [markdown]
# ###  Let's calculate and plot total consumption amounts (in tons/acre) each hour

# %%
### Calculate total fuel consumption by adding flaming and smoldering consumption
fofem_outputs['total_consumed'] = fofem_outputs['consumed_flaming'] + fofem_outputs['consumed_smoldering']

# Get consumption for each hour
total_cons = fofem_outputs.groupby('date_time')[['total_consumed', 'consumed_smoldering','consumed_flaming']].first()

total_cons = total_cons.reset_index(drop=False)

# Datetime conversions
total_cons['date_time'] = pd.to_datetime(total_cons['date_time'], format='%Y%m%d%H')

# %%
### Plot hourly consumption (tons/acre) for the first full 3 days of the fire
fig, ax  = plt.subplots(figsize=(8, 4))
total_cons = total_cons[(total_cons['date_time'] >= '2020-09-05 00:00:00') & (total_cons['date_time'] <= '2020-09-08 00:00:00')]

# Plot fuel consumption
ax.plot(total_cons['date_time'], total_cons['total_consumed'], color = 'darkgreen', label = f"Fuel Consumption", linewidth=2.5)

# Set plot titles and axis labels
ax.set_title(f"Creek Fire Fuel Consumption", size=16)
ax2.set_title(f"Creek Fire Smoldering Consumption", size=16)
ax.set_xlabel('Time (UTC)', size=14)
ax2.set_xlabel('Time (UTC)', size=14)
ax.set_ylabel(f"Fuel Consumed (tons/acre)", size = 14, labelpad = 12)

# set font and rotation for date tick labels
ax.tick_params(axis='x', labelsize=8,rotation=45,which='major')
ax2.tick_params(axis='x', labelsize=8,rotation=45,which='major')

# Add plot legends
ax.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax.transAxes, fontsize= 'small')
ax2.legend(loc="upper right", bbox_to_anchor=(2.2,1), bbox_transform=ax.transAxes, fontsize= 'small')
plt.show()

# %% [markdown]
# ## Now let's run the Freitas et al. 2010 plume rise model!
#
# #### Inputs to the Freitas model include:
# - Heat fluxes (kW m-2)
# - Active burn area (m2)
# - Thermodynamic profile
# - Entrainment coefficient
#     - Note: this controls the amount of cooler, environmental air entrained into the plume
# - Wind shear effects (off/on)
#
# #### Outputs include:
# - Plume top height (AGL)
# - detrainment profile

# %% [markdown]
# ### First switch to the directory where it's installed

# %%
### Change working directory to where the Freitas plume rise model is installed
from pathlib import Path
project_root = Path('/uufs/chpc.utah.edu/common/home/u6043241/lin-group18/CW/plumerise/Plume-model_stand_alone/')

sys.path.append(str(project_root))
os.chdir(project_root)

from MP_FA_multi_plume_rise_demo import process_row, worker_init, process_row_parallel

# %%
### Format datetime
mean_hf['new_datetime'] = pd.to_datetime(mean_hf['new_datetime']).dt.strftime("%Y-%m-%dT%H:%M:%S")

## Convert hourly growth from acres to m^2
mean_hf['hourly_growth'] = mean_hf['hourly_growth'] * 4046.86 

### Parallelize
def process_row_parallel(row):
    result = process_row(row)
    return result

if __name__ == "__main__":
    num_processes = int(os.environ.get("SLURM_CPUS_PER_TASK", mp.cpu_count()))

    # Use existing DataFrame directly
    model_inputs = mean_hf.values.tolist()

    # Optional if you still need headers
    header = mean_hf.columns.tolist()

    with mp.Pool(
        processes=num_processes,
        initializer=worker_init
    ) as pool:
        results = pool.map(process_row_parallel, model_inputs)

    for pid in pool._pool:
        worker_dir = f"/tmp/worker_{pid}_"  #make sure that temporary directories for each worker process are deleted
        if os.path.exists(worker_dir):
            shutil.rmtree(worker_dir, ignore_errors=True)
    
    # Write results to CSV files
    cols = ['date_time', 'lat', 'lon', 'fire_id', 'fire_area', 'heat_flux', 'pth', 'output_filepath']
    output_df = pd.DataFrame(results, columns=cols)
    # output_df.to_csv('/uufs/chpc.utah.edu/common/home/u6043241/fire_atlas/run_fofem/paper_demo/outputs/5_26_creek_demo_pr_out.csv', index=False)
# Out:
# Creating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist file
# Creating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist file
# Creating Freitas model namelist fileCreating Freitas model namelist file
#
# Creating Freitas model namelist file
#
# Creating Freitas model namelist file
# Formating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist file
# Creating Freitas model namelist file
# Creating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas model
# Creating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist file
# Creating Freitas model namelist file
#
# Creating Freitas model namelist fileCreating Freitas model namelist file
# Creating Freitas model namelist file
# Creating Freitas model namelist fileCreating Freitas model namelist file
# Creating Freitas model namelist fileCreating Freitas model namelist file
#
#
#
#
# Creating Freitas model namelist file
# Creating Freitas model namelist file
#
# Formating input thermodynamic profile for the Freitas modelCreating Freitas model namelist file
#
#
#
# Formating input thermodynamic profile for the Freitas modelCreating Freitas model namelist file
#
# Formating input thermodynamic profile for the Freitas modelCreating Freitas model namelist file
#
# Creating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas model
#
#
#
# Formating input thermodynamic profile for the Freitas model
#
#
# Formating input thermodynamic profile for the Freitas model
# Creating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
#
# Creating Freitas model namelist fileFormating input thermodynamic profile for the Freitas model
#
# Creating Freitas model namelist file
#
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist file
#
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist file
# Formating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
#
#
# Creating Freitas model namelist fileFormating input thermodynamic profile for the Freitas model
#
#
# Formating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist file
#
# Formating input thermodynamic profile for the Freitas modelCreating Freitas model namelist fileCreating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelCreating Freitas model namelist file
#
#
#
#
#
#
# Formating input thermodynamic profile for the Freitas model
# Creating Freitas model namelist file
#
# Creating Freitas model namelist file
#
# Formating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
#
#
#
#
#
# Formating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
#
# Formating input thermodynamic profile for the Freitas model
#
#
#
# Formating input thermodynamic profile for the Freitas model
# Creating Freitas model namelist fileCreating Freitas model namelist fileFormating input thermodynamic profile for the Freitas model
#
#
#
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
#
# Formating input thermodynamic profile for the Freitas model
#
# Creating Freitas model namelist file
#
#
#
#
#
# Formating input thermodynamic profile for the Freitas model
#
#
# Formating input thermodynamic profile for the Freitas model
#
# Formating input thermodynamic profile for the Freitas model
#
#
#
#
# Creating Freitas model namelist fileFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
#
#
#
#
# Formating input thermodynamic profile for the Freitas model
#
#
# Formating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
#
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
# Formating input thermodynamic profile for the Freitas model
#
#
#
# Formating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas modelFormating input thermodynamic profile for the Freitas model
#
#
#
#
#
# Formating input thermodynamic profile for the Freitas model
#
#
#
#
#
# Formating input thermodynamic profile for the Freitas model
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T09:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T14:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T12:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T04:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T11:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T06:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    304.881439       1.89999998       15809.4873
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    188.385666       1.00000000       15681.7578
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T14:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T23:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    2125.21851       7.40000010       15379.5400
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T10:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T08:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T15:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T13:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-05T00:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    165.153275      0.899999976       15686.7939
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    252.576157       1.10000002       15683.5107
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    178.987457       1.00000000       15694.2061
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T17:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-07T07:00:00 successfully completed
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T00:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    368.099701       1.29999995       15679.5635
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T21:00:00 successfully completed
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    981.049500       5.40000010       15362.9883
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    195.963730       4.09999990       15891.3418
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    505.336456       2.20000005       15862.3232
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T13:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T12:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T16:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-07T15:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T11:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    168.906387      0.899999976       15800.7783
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    450.131500       2.09999990       15205.0156
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    282.030823       1.79999995       15878.2754
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    164.739670      0.899999976       15673.3125
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T06:00:00 successfully completed
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    450.933899       2.09999990       15200.2139
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T22:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    377.089661       2.00000000       15823.9521
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    194.147339       1.00000000       15681.8945
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T21:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    499.604462       6.09999990       15435.1172
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T01:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    447.717438       2.09999990       15200.5625
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T02:00:00 successfully completed
#
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T14:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    282.522339       1.79999995       15803.0576
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    824.050232       6.09999990       15754.4180
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T04:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    1524.61047       7.09999990       15290.5693
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T05:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T19:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T03:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T15:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    356.737946       1.70000005       15818.6826
#
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T10:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-07T21:00:00 successfully completed
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T18:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    940.400208       5.59999990       15405.9590
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    674.197876       4.30000019       15428.2559
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T18:00:00 successfully completed
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    400.276733       7.69999981       15388.6221
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    269.058350       4.30000019       15302.6699
#
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T03:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    572.236877       2.29999995       15850.7285
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T20:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T08:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    491.141693       2.09999990       15262.5117
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    490.720398       4.90000010       15368.2207
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T12:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    442.072601       1.79999995       15194.6162
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    151.718582       3.90000010       15856.2656
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T06:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    272.225067       1.79999995       15798.0254
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T23:00:00 successfully completed
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T07:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    7546.14404       9.30000019       15390.7168
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T02:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    539.694702       5.50000000       15691.8408
#
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T09:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    215.136154       1.10000002       15679.3545
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    406.624054       4.50000000       15844.7012
#
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    1491.04248       7.69999981       15430.7295
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    452.060638       2.09999990       15198.3457
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T05:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    409.021912       1.79999995       15821.0967
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    381.903168       1.70000005       15818.5020
#
#
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    453.374115       2.09999990       15197.4043
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T03:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T13:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    171.698853      0.899999976       15674.5781
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    3125.21924       8.00000000       15394.8691
#
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    446.738586       2.09999990       15200.2900
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T16:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    493.161438       8.19999981       15936.5391
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T22:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    318.589050       1.20000005       15685.0811
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    669.675354       5.09999990       15268.1299
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    317.560760       4.30000019       15834.6982
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    720.379761       4.30000019       15430.2627
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T16:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-07T04:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    4774.04932       8.69999981       15396.4639
#
#
# temporary dir path:
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    267.312469       4.19999981       15931.3516
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T01:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    664.201660       2.40000010       15875.6104
#
#
# temporary dir path:Plume rise simulation for 2020-CASNF-001391_2020-09-07T23:00:00 successfully completed/scratch/local/u6043241/13501025/worker_2269343_iv_x29ub/tmpp8eu5t_n
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    1128.44995       6.59999990       15222.7246
# temporary dir path:Plume rise simulation for 2020-CASNF-001391_2020-09-07T05:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T19:00:00 successfully completed
#
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    613.077332       2.40000010       15866.5840
#
# /scratch/local/u6043241/13501025/worker_2269311_2jmxmrqe/tmpcsi146d5
# temporary dir path: Plume rise simulation for 2020-CASNF-001391_2020-09-07T08:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    1598.98694       5.40000010       15423.1113
# /scratch/local/u6043241/13501025/worker_2269299_cnuti3ls/tmpbstz8skd
# /scratch/local/u6043241/13501025/worker_2269305_q22z9rpr/tmp8rond0le
#
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    415.519012       7.80000019       15412.2363
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    440.936615       2.20000005       15843.7080
#
# temporary dir path:Plume rise simulation for 2020-CASNF-001391_2020-09-07T18:00:00 successfully completed
# /scratch/local/u6043241/13501025/worker_2269348_sze6q0yt/tmpijwzgdo_
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    360.013031       4.40000010       15383.9834
#
#
# temporary dir path:Plume rise simulation for 2020-CASNF-001391_2020-09-07T11:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-06T20:00:00 successfully completed Plume rise simulation for 2020-CASNF-001391_2020-09-06T07:00:00 successfully completed
#
#
# /scratch/local/u6043241/13501025/worker_2269301_8nqw8xpv/tmpv0awgma9
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    451.271912       8.00000000       15429.4268
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    330.292664       1.89999998       15811.4766
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    426.724609       1.79999995       15824.7852
#
#
#
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T01:00:00 successfully completed
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T09:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    645.197205       5.00000000       15312.2842
#
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    399.176331       2.00000000       15832.8086
# temporary dir path:temporary dir path:
#   /scratch/local/u6043241/13501025/worker_2269312_e8z57yr3/tmpdukdybfetemporary dir path:/scratch/local/u6043241/13501025/worker_2269351_6kdysyqq/tmpd3vamoe4
#
# /scratch/local/u6043241/13501025/worker_2269333_pm8jfvyg/tmplqwx6gln
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T17:00:00 successfully completed
# temporary dir path:
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    404.743591       7.80000019       15972.2832
#
# /scratch/local/u6043241/13501025/worker_2269297_iw9bjyn5/tmp9ht6_j1a
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T00:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    1143.55249       5.80000019       15433.3281
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-05T10:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    184.029556       1.00000000       15678.7744
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-06T22:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    542.411011       6.19999981       15437.9668
# temporary dir path:
#  Plume rise simulation for 2020-CASNF-001391_2020-09-08T00:00:00 successfully completedPlume rise simulation for 2020-CASNF-001391_2020-09-07T17:00:00 successfully completed/scratch/local/u6043241/13501025/worker_2269350_ikt19lab/tmpv1k5wogr
# temporary dir path:
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T20:00:00 successfully completed
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    268.329437       4.19999981       15291.6650
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    295.387756       4.30000019       16126.4805
#
#
# /scratch/local/u6043241/13501025/worker_2269335_tllfs5ov/tmpahtr5yrr
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    601.825378       4.80000019       15430.6279
#
#
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269310_z1v_btw0/tmpdyr346aw
# temporary dir path:temporary dir path:temporary dir path:temporary dir path:   /scratch/local/u6043241/13501025/worker_2269318_njhulgkl/tmp9u7ks74o /scratch/local/u6043241/13501025/worker_2269342_pgkw7wyn/tmp4slee1pu/scratch/local/u6043241/13501025/worker_2269330_rex66xyj/tmpkk_cso5m
#
# /scratch/local/u6043241/13501025/worker_2269324_l5pkzk1i/tmprflsk9gn
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T19:00:00 successfully completed
#
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    509.742035       4.69999981       15414.6562
# temporary dir path:
#  /scratch/local/u6043241/13501025/worker_2269327_6d3g2212/tmpzop51cyc
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269279__d5vepwj/tmplv2s0qjp
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269357_4brqnmx9/tmpkujuuvae
# temporary dir path:temporary dir path:  /scratch/local/u6043241/13501025/worker_2269266_ht6eannr/tmph4adwv3p/scratch/local/u6043241/13501025/worker_2269316_uc3wb3_y/tmpkooayz6h
#
# Plume rise simulation for 2020-CASNF-001391_2020-09-07T02:00:00 successfully completed
#
#  Writing final output for simulation
#   burnt_area (ha) - top cloud(km)- power (W m^2)
#    698.026794       5.19999981       15282.3408
#
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269306_vfyurb03/tmp13903xtftemporary dir path:
#  /scratch/local/u6043241/13501025/worker_2269358_zb7ivfll/tmpn1vzqx9v
# temporary dir path:temporary dir path: temporary dir path:/scratch/local/u6043241/13501025/worker_2269295_n_wj5l4y/tmpckf1ljgj
# /scratch/local/u6043241/13501025/worker_2269308_4ogzu19m/tmphpf_56my/scratch/local/u6043241/13501025/worker_2269317_m34js3oz/tmp2_mfkxqk
#
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269328_vpwiam7e/tmplv_jsts_
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269314_ui683vz7/tmpfvfpv34z
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269302_buf6vtxj/tmp8k5aple5
# temporary dir path:temporary dir path:temporary dir path:temporary dir path:temporary dir path: temporary dir path:   /scratch/local/u6043241/13501025/worker_2269296_ld51izlc/tmp4mxahw38/scratch/local/u6043241/13501025/worker_2269352_1lwgsif1/tmpm9oplju_
# /scratch/local/u6043241/13501025/worker_2269325_wa3dc35c/tmpamhnb1e3/scratch/local/u6043241/13501025/worker_2269294_7rgcly0y/tmp1mifha2ztemporary dir path:
#
#
#  /scratch/local/u6043241/13501025/worker_2269340_crvl6qbs/tmpmt8aqcaq/scratch/local/u6043241/13501025/worker_2269285_ue8f79p2/tmpwes9iron
#
# /scratch/local/u6043241/13501025/worker_2269319_8769esbl/tmpjncwko2e
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269286_cpj6e_4m/tmpn6xgzspp
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269293__5g8wroo/tmpy8tpelzs
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269329_avyicvxx/tmpvbsscy95
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269313_ywv87xpv/tmp1418i_z3
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269354_gxu2ikmf/tmp8yh14budtemporary dir path:temporary dir path:
#   /scratch/local/u6043241/13501025/worker_2269334_rj162kem/tmpwasa24fk/scratch/local/u6043241/13501025/worker_2269331_3sbz0nrc/tmpyu70t9au
#
# temporary dir path:temporary dir path:  /scratch/local/u6043241/13501025/worker_2269322_3u2ybjs6/tmpdp25_7mh/scratch/local/u6043241/13501025/worker_2269356_8o_vwiny/tmpy8eqat_i
#
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269332_ag_6i1i3/tmpj0zai6xd
# temporary dir path:temporary dir path: /scratch/local/u6043241/13501025/worker_2269349_bnd_ahfc/tmpyft8z9u3 temporary dir path:
# /scratch/local/u6043241/13501025/worker_2269321_imrwwf45/tmp38zfw1mh
# /scratch/local/u6043241/13501025/worker_2269300_qmv9mezr/tmplx_p66ri
# temporary dir path:temporary dir path:  /scratch/local/u6043241/13501025/worker_2269320_dwxytkgw/tmpss3qm84c/scratch/local/u6043241/13501025/worker_2269315_cxfbi758/tmph2mklmgm
# temporary dir path:
#  temporary dir path:/scratch/local/u6043241/13501025/worker_2269341_ncdcuds1/tmpz9xdj3tf
# /scratch/local/u6043241/13501025/worker_2269346_b5wq1b7p/tmp6z3y__ol
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269307_ix6fpxxq/tmpl5e_0_7x
# temporary dir path: temporary dir path:/scratch/local/u6043241/13501025/worker_2269303_9gbtzeln/tmpyrjf28lo
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269304_mx7peash/tmpoeq77qjvtemporary dir path:/scratch/local/u6043241/13501025/worker_2269353_co2x4by2/tmp3weeehhd
#
# temporary dir path:/scratch/local/u6043241/13501025/worker_2269339_i0euke94/tmpqm231qex temporary dir path:/scratch/local/u6043241/13501025/worker_2269337_va4vzf3q/tmpf5tzk9w5
#
# temporary dir path:/scratch/local/u6043241/13501025/worker_2269323_xsyyzsus/tmpk2sem_2dtemporary dir path:temporary dir path:
#   temporary dir path: /scratch/local/u6043241/13501025/worker_2269344_ijoapt54/tmp3zy5e7oc/scratch/local/u6043241/13501025/worker_2269273_k7d98hy7/tmprkihskwb/scratch/local/u6043241/13501025/worker_2269326_ag9ex997/tmpg8x6siaf
#
#
# /scratch/local/u6043241/13501025/worker_2269345_2am8l6_8/tmpu_k3yoq6
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269298_ijg7k6xn/tmpuf2xnq8f
# temporary dir path: temporary dir path:/scratch/local/u6043241/13501025/worker_2269309_0y48x4gs/tmpgfg_prni
# /scratch/local/u6043241/13501025/worker_2269360_cc4fdeum/tmpd13dz5_d
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269359_7j_mt8nu/tmpnp52hhzv
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269347_kh2lid5_/tmpm_k8dm9h
# temporary dir path:temporary dir path:  /scratch/local/u6043241/13501025/worker_2269336_jvqzbc1u/tmp5096frf5/scratch/local/u6043241/13501025/worker_2269355_lpay095z/tmp9nukyhj5
#
# temporary dir path: /scratch/local/u6043241/13501025/worker_2269338_k7l5pux4/tmpr6r0r5ju

# %% [markdown]
# ## Plot a time series of plume top heights for the Creek Fire

# %%
### Plot plume rise heights for the first few days of the Creek Fire
fig, ax  = plt.subplots(figsize=(8, 4))

# Plot plume top heights
output_df['date_time'] = pd.to_datetime(output_df['date_time'])
ax.plot(output_df['date_time'], output_df['pth'], color = 'darkred', label = f"Plume Top Heights", linewidth=2.5)

# Set plot titles and axis labels
ax.set_title(f"Creek Fire Plume Top Heights (AGL)", size=16)
ax.set_xlabel('Time (UTC)', size=14)
ax.set_ylabel(f"Plume Top Height (km)", size = 14, labelpad = 12)

# set font and rotation for date tick labels
ax.tick_params(axis='x', labelsize=8,rotation=45,which='major')

# Add plot legends
ax.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax.transAxes, fontsize= 'small')
plt.gcf().autofmt_xdate() 
plt.show()
